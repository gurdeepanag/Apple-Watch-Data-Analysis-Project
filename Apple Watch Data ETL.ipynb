# %% [markdown]
# # My Apple Watch Data Analysis
# Gurdeep Panag
# February 7th, 2024

# %%
import pandas as pd 
import datetime as dt 
import xml.etree.ElementTree as ET

# %% [markdown]
# ## Data Collection and Cleaning in Record

# %%
# Parsing the XML file "export.xml" and storing the resulting tree structure in the 'tree' variable
tree = ET.parse("export.xml")

# Displaying the parsed XML tree object
tree

# %%
# Getting the root element of the XML tree
root = tree.getroot()

# Creating a list comprehension to extract attributes of each 'Record' element in the XML
# The resulting list, 'record_list', will contain dictionaries where each dictionary represents the attributes of a 'Record' element
record_list = [x.attrib for x in root.iter('Record')]

# Displaying the list of dictionaries containing attributes of 'Record' elements
record_list
# Out:
# [{'type': 'HKQuantityTypeIdentifierHeight',
#   'sourceName': 'Health',
#   'sourceVersion': '11.2.6',
#   'unit': 'cm',
#   'creationDate': '2018-03-16 19:55:19 -0700',
#   'startDate': '2018-03-16 19:55:19 -0700',
#   'endDate': '2018-03-16 19:55:19 -0700',
#   'value': '180'},
#  {'type': 'HKQuantityTypeIdentifierHeight',
#   'sourceName': 'Health',
#   'sourceVersion': '13.0',
#   'unit': 'cm',
#   'creationDate': '2019-09-19 23:41:11 -0700',
#   'startDate': '2019-09-19 23:41:11 -0700',
#   'endDate': '2019-09-19 23:41:11 -0700',
#   'value': '177.8'},
#  {'type': 'HKQuantityTypeIdentifierHeight',
#   'sourceName': "Gurdeep's iPhone 12 Pro Max",
#   'sourceVersion': '17.0',
#   'unit': 'cm',
#   'creationDate': '2023-09-22 23:31:09 -0700',
#   'startDate': '2023-09-22 23:31:09 -0700',
#   'endDate': '2023-09-22 23:31:09 -0700',
#   'value': '180'},
#  {'type': 'HKQuantityTypeIdentifierBodyMass',
#   'sourceName': 'Health',
#   'sourceVersion': '11.2.6',
#   'unit': 'kg',
#   'creationDate': '2018-03-16 19:55:19 -0700',
#   'startDate': '2018-03-16 19:55:19 -0700',
#   'endDate': '2018-03-16 19:55:19 -0700',
#   'value': '70'},
#  {'type': 'HKQuantityTypeIdentifierBodyMass',
#   'sourceName': 'Health',
#   'sourceVersion': '13.0',
#   'unit': 'kg',
#   'creationDate': '2019-09-19 23:41:11 -0700',
#   'startDate': '2019-09-19 23:41:11 -0700',
#   'endDate': '2019-09-19 23:41:11 -0700',
#   'value': '70.7604'},
#  {'type': 'HKQuantityTypeIdentifierBodyMass',
#   'sourceName': 'Health',
#   'sourceVersion': '13.3.1',
#   'unit': 'kg',
#   'creationDate': '2020-03-10 19:07:45 -0700',
#   'startDate': '2020-03-10 19:07:00 -0700',
#   'endDate': '2020-03-10 19:07:00 -0700',
#   'value': '74.8'},
#  {'type': 'HKQuantityTypeIdentifierBodyMass',
#   'sourceName': "Gurdeep's iPhone 12 Pro Max",
#   'sourceVersion': '16.1.1',
#   'unit': 'kg',
#   'creationDate': '2022-11-12 20:16:25 -0700',
#   'startDate': '2022-11-12 20:16:25 -0700',
#   'endDate': '2022-11-12 20:16:25 -0700',
#   'value': '79'},
#  {'type': 'HKQuantityTypeIdentifierBodyMass',
#   'sourceName': "Gurdeep's iPhone 12 Pro Max",
#   'sourceVersion': '17.0',
#   'unit': 'kg',
#   'creationDate': '2023-09-22 23:31:09 -0700',
#   'startDate': '2023-09-22 23:31:09 -0700',
#   'endDate': '2023-09-22 23:31:09 -0700',
#   'value': '74'},
#  {'type': 'HKQuantityTypeIdentifierBodyMass',
#   'sourceName': 'MyFitnessPal',
#   'sourceVersion': '46181',
#   'unit': 'kg',
#   'creationDate': '2023-09-23 09:40:47 -0700',
#   'startDate': '2023-08-05 09:40:00 -0700',
#   'endDate': '2023-08-05 09:40:00 -0700',
#   'value': '73.5001'},
#  {'type': 'HKQuantityTypeIdentifierBodyMass',
#   'sourceName': 'MyFitnessPal',
#   'sourceVersion': '46181',
#   'unit': 'kg',
#   'creationDate': '2023-09-23 09:48:38 -0700',
#   'startDate': '2023-09-23 09:48:00 -0700',
#   'endDate': '2023-09-23 09:48:00 -0700',
#   'value': '74'},
#  {'type': 'HKQuantityTypeIdentifierBodyMass',
#   'sourceName': 'MyFitnessPal',
#   'sourceVersion': '46391',
#   'unit': 'kg',
#   'creationDate': '2023-09-24 08:36:34 -0700',
#   'startDate': '2023-09-22 08:36:00 -0700',
#   'endDate': '2023-09-22 08:36:00 -0700',
#   'value': '74'},
#  {'type': 'HKQuantityTypeIdentifierBodyMass',
#   'sourceName': 'MyFitnessPal',
#   'sourceVersion': '46391',
#   'unit': 'kg',
#   'creationDate': '2023-09-24 09:45:49 -0700',
#   'startDate': '2023-09-22 09:45:00 -0700',
#   'endDate': '2023-09-22 09:45:00 -0700',
#   'value': '74'},
#  {'type': 'HKQuantityTypeIdentifierBodyMass',
#   'sourceName': 'MyFitnessPal',
#   'sourceVersion': '47099',
#   'unit': 'kg',
#   'creationDate': '2023-10-28 09:37:13 -0700',
#   'startDate': '2023-09-24 09:37:00 -0700',
#   'endDate': '2023-09-24 09:37:00 -0700',
#   'value': '72.7'},
#  {'type': 'HKQuantityTypeIdentifierBodyMass',
#   'sourceName': 'MyFitnessPal',
#   'sourceVersion': '47445',
#   'unit': 'kg',
#   'creationDate': '2023-11-28 11:09:53 -0700',
#   'startDate': '2023-10-28 10:09:00 -0700',
#   'endDate': '2023-10-28 10:09:00 -0700',
#   'value': '75.5'},
#  {'type': 'HKQuantityTypeIdentifierBodyMass',
#   'sourceName': 'MyFitnessPal',
#   'sourceVersion': '47445',
#   'unit': 'kg',
#   'creationDate': '2023-12-02 12:17:25 -0700',
#   'startDate': '2023-11-28 12:17:00 -0700',
#   'endDate': '2023-11-28 12:17:00 -0700',
#   'value': '75.7'},
#  {'type': 'HKQuantityTypeIdentifierBodyMass',
#   'sourceName': 'MyFitnessPal',
#   'sourceVersion': '47445',
#   'unit': 'kg',
#   'creationDate': '2023-12-02 19:25:19 -0700',
#   'startDate': '2023-12-02 19:25:00 -0700',
#   'endDate': '2023-12-02 19:25:00 -0700',
#   'value': '75.7'},
#  {'type': 'HKQuantityTypeIdentifierBodyMass',
#   'sourceName': 'Health',
#   'sourceVersion': '17.1.2',
#   'unit': 'kg',
#   'creationDate': '2024-01-10 11:57:45 -0700',
#   'startDate': '2024-01-10 11:57:00 -0700',
#   'endDate': '2024-01-10 11:57:00 -0700',
#   'value': '76'},
#  {'type': 'HKQuantityTypeIdentifierBodyMass',
#   'sourceName': 'Health',
#   'sourceVersion': '17.1.2',
#   'unit': 'kg',
#   'creationDate': '2024-01-13 11:30:03 -0700',
#   'startDate': '2024-01-13 11:29:00 -0700',
#   'endDate': '2024-01-13 11:29:00 -0700',
#   'value': '76'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-22 23:31:07 -0700',
#   'startDate': '2023-09-22 23:30:26 -0700',
#   'endDate': '2023-09-22 23:30:26 -0700',
#   'value': '61'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-22 23:33:25 -0700',
#   'startDate': '2023-09-22 23:32:21 -0700',
#   'endDate': '2023-09-22 23:32:21 -0700',
#   'value': '65.6369'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-22 23:36:02 -0700',
#   'startDate': '2023-09-22 23:35:34 -0700',
#   'endDate': '2023-09-22 23:35:34 -0700',
#   'value': '63'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-22 23:41:02 -0700',
#   'startDate': '2023-09-22 23:38:58 -0700',
#   'endDate': '2023-09-22 23:38:58 -0700',
#   'value': '62'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-22 23:50:26 -0700',
#   'startDate': '2023-09-22 23:41:31 -0700',
#   'endDate': '2023-09-22 23:41:31 -0700',
#   'value': '68'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-22 23:55:58 -0700',
#   'startDate': '2023-09-22 23:52:34 -0700',
#   'endDate': '2023-09-22 23:52:34 -0700',
#   'value': '68'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 00:01:03 -0700',
#   'startDate': '2023-09-22 23:57:23 -0700',
#   'endDate': '2023-09-22 23:57:23 -0700',
#   'value': '69'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 00:06:03 -0700',
#   'startDate': '2023-09-23 00:05:08 -0700',
#   'endDate': '2023-09-23 00:05:08 -0700',
#   'value': '64'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 00:11:03 -0700',
#   'startDate': '2023-09-23 00:06:15 -0700',
#   'endDate': '2023-09-23 00:06:15 -0700',
#   'value': '65'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 00:15:03 -0700',
#   'startDate': '2023-09-23 00:15:01 -0700',
#   'endDate': '2023-09-23 00:15:01 -0700',
#   'value': '69'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 00:15:07 -0700',
#   'startDate': '2023-09-23 00:15:05 -0700',
#   'endDate': '2023-09-23 00:15:05 -0700',
#   'value': '64'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 00:15:12 -0700',
#   'startDate': '2023-09-23 00:15:11 -0700',
#   'endDate': '2023-09-23 00:15:11 -0700',
#   'value': '64'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 00:15:17 -0700',
#   'startDate': '2023-09-23 00:15:16 -0700',
#   'endDate': '2023-09-23 00:15:16 -0700',
#   'value': '62'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 00:15:22 -0700',
#   'startDate': '2023-09-23 00:15:17 -0700',
#   'endDate': '2023-09-23 00:15:17 -0700',
#   'value': '70'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 00:15:27 -0700',
#   'startDate': '2023-09-23 00:15:26 -0700',
#   'endDate': '2023-09-23 00:15:26 -0700',
#   'value': '75'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 00:15:32 -0700',
#   'startDate': '2023-09-23 00:15:29 -0700',
#   'endDate': '2023-09-23 00:15:29 -0700',
#   'value': '78'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 00:15:37 -0700',
#   'startDate': '2023-09-23 00:15:33 -0700',
#   'endDate': '2023-09-23 00:15:33 -0700',
#   'value': '82'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 00:15:42 -0700',
#   'startDate': '2023-09-23 00:15:37 -0700',
#   'endDate': '2023-09-23 00:15:37 -0700',
#   'value': '82'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 00:16:03 -0700',
#   'startDate': '2023-09-23 00:14:18 -0700',
#   'endDate': '2023-09-23 00:14:18 -0700',
#   'value': '62'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 00:17:58 -0700',
#   'startDate': '2023-09-23 00:17:56 -0700',
#   'endDate': '2023-09-23 00:17:56 -0700',
#   'value': '65'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 00:18:02 -0700',
#   'startDate': '2023-09-23 00:18:01 -0700',
#   'endDate': '2023-09-23 00:18:01 -0700',
#   'value': '62'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 00:18:07 -0700',
#   'startDate': '2023-09-23 00:18:06 -0700',
#   'endDate': '2023-09-23 00:18:06 -0700',
#   'value': '61'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 00:18:13 -0700',
#   'startDate': '2023-09-23 00:18:09 -0700',
#   'endDate': '2023-09-23 00:18:09 -0700',
#   'value': '61'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 00:18:17 -0700',
#   'startDate': '2023-09-23 00:18:16 -0700',
#   'endDate': '2023-09-23 00:18:16 -0700',
#   'value': '59'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 00:21:01 -0700',
#   'startDate': '2023-09-23 00:19:37 -0700',
#   'endDate': '2023-09-23 00:19:37 -0700',
#   'value': '60'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 00:26:06 -0700',
#   'startDate': '2023-09-23 00:21:35 -0700',
#   'endDate': '2023-09-23 00:21:35 -0700',
#   'value': '61'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 00:32:19 -0700',
#   'startDate': '2023-09-23 00:30:14 -0700',
#   'endDate': '2023-09-23 00:30:14 -0700',
#   'value': '54'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 00:36:20 -0700',
#   'startDate': '2023-09-23 00:31:24 -0700',
#   'endDate': '2023-09-23 00:31:24 -0700',
#   'value': '53'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 00:46:21 -0700',
#   'startDate': '2023-09-23 00:36:04 -0700',
#   'endDate': '2023-09-23 00:36:04 -0700',
#   'value': '54'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 00:46:21 -0700',
#   'startDate': '2023-09-23 00:40:59 -0700',
#   'endDate': '2023-09-23 00:40:59 -0700',
#   'value': '55'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 00:59:42 -0700',
#   'startDate': '2023-09-23 00:46:20 -0700',
#   'endDate': '2023-09-23 00:46:20 -0700',
#   'value': '55'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 00:59:42 -0700',
#   'startDate': '2023-09-23 00:51:22 -0700',
#   'endDate': '2023-09-23 00:51:22 -0700',
#   'value': '56'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 01:10:01 -0700',
#   'startDate': '2023-09-23 00:56:04 -0700',
#   'endDate': '2023-09-23 00:56:04 -0700',
#   'value': '56'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 01:10:01 -0700',
#   'startDate': '2023-09-23 01:00:56 -0700',
#   'endDate': '2023-09-23 01:00:56 -0700',
#   'value': '56'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 01:17:44 -0700',
#   'startDate': '2023-09-23 01:06:01 -0700',
#   'endDate': '2023-09-23 01:06:01 -0700',
#   'value': '57'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 01:17:44 -0700',
#   'startDate': '2023-09-23 01:10:56 -0700',
#   'endDate': '2023-09-23 01:10:56 -0700',
#   'value': '57'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 01:23:00 -0700',
#   'startDate': '2023-09-23 01:19:27 -0700',
#   'endDate': '2023-09-23 01:19:27 -0700',
#   'value': '51'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 01:27:41 -0700',
#   'startDate': '2023-09-23 01:23:07 -0700',
#   'endDate': '2023-09-23 01:23:07 -0700',
#   'value': '53'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 01:35:50 -0700',
#   'startDate': '2023-09-23 01:26:17 -0700',
#   'endDate': '2023-09-23 01:26:17 -0700',
#   'value': '55'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 01:36:06 -0700',
#   'startDate': '2023-09-23 01:31:22 -0700',
#   'endDate': '2023-09-23 01:31:22 -0700',
#   'value': '54'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 01:49:03 -0700',
#   'startDate': '2023-09-23 01:35:57 -0700',
#   'endDate': '2023-09-23 01:35:57 -0700',
#   'value': '54'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 01:49:03 -0700',
#   'startDate': '2023-09-23 01:41:47 -0700',
#   'endDate': '2023-09-23 01:41:47 -0700',
#   'value': '52'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 01:54:28 -0700',
#   'startDate': '2023-09-23 01:46:27 -0700',
#   'endDate': '2023-09-23 01:46:27 -0700',
#   'value': '51'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 01:59:35 -0700',
#   'startDate': '2023-09-23 01:52:47 -0700',
#   'endDate': '2023-09-23 01:52:47 -0700',
#   'value': '54'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 02:09:36 -0700',
#   'startDate': '2023-09-23 01:57:32 -0700',
#   'endDate': '2023-09-23 01:57:32 -0700',
#   'value': '55'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 02:09:36 -0700',
#   'startDate': '2023-09-23 02:01:12 -0700',
#   'endDate': '2023-09-23 02:01:12 -0700',
#   'value': '55'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 02:27:19 -0700',
#   'startDate': '2023-09-23 02:06:02 -0700',
#   'endDate': '2023-09-23 02:06:02 -0700',
#   'value': '55'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 02:27:19 -0700',
#   'startDate': '2023-09-23 02:11:47 -0700',
#   'endDate': '2023-09-23 02:11:47 -0700',
#   'value': '54'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 02:27:20 -0700',
#   'startDate': '2023-09-23 02:16:47 -0700',
#   'endDate': '2023-09-23 02:16:47 -0700',
#   'value': '55'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 02:27:20 -0700',
#   'startDate': '2023-09-23 02:24:22 -0700',
#   'endDate': '2023-09-23 02:24:22 -0700',
#   'value': '59'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 02:31:50 -0700',
#   'startDate': '2023-09-23 02:29:03 -0700',
#   'endDate': '2023-09-23 02:29:03 -0700',
#   'value': '56'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 02:37:29 -0700',
#   'startDate': '2023-09-23 02:33:17 -0700',
#   'endDate': '2023-09-23 02:33:17 -0700',
#   'value': '60'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 02:45:52 -0700',
#   'startDate': '2023-09-23 02:36:16 -0700',
#   'endDate': '2023-09-23 02:36:16 -0700',
#   'value': '64'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 02:47:30 -0700',
#   'startDate': '2023-09-23 02:41:32 -0700',
#   'endDate': '2023-09-23 02:41:32 -0700',
#   'value': '70'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 02:54:19 -0700',
#   'startDate': '2023-09-23 02:45:57 -0700',
#   'endDate': '2023-09-23 02:45:57 -0700',
#   'value': '73'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 03:04:20 -0700',
#   'startDate': '2023-09-23 02:51:27 -0700',
#   'endDate': '2023-09-23 02:51:27 -0700',
#   'value': '58'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 03:04:21 -0700',
#   'startDate': '2023-09-23 02:56:07 -0700',
#   'endDate': '2023-09-23 02:56:07 -0700',
#   'value': '55'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 03:11:37 -0700',
#   'startDate': '2023-09-23 03:01:36 -0700',
#   'endDate': '2023-09-23 03:01:36 -0700',
#   'value': '56'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 03:15:25 -0700',
#   'startDate': '2023-09-23 03:06:42 -0700',
#   'endDate': '2023-09-23 03:06:42 -0700',
#   'value': '56'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 03:25:26 -0700',
#   'startDate': '2023-09-23 03:11:07 -0700',
#   'endDate': '2023-09-23 03:11:07 -0700',
#   'value': '56'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 03:25:26 -0700',
#   'startDate': '2023-09-23 03:15:57 -0700',
#   'endDate': '2023-09-23 03:15:57 -0700',
#   'value': '57'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 03:35:25 -0700',
#   'startDate': '2023-09-23 03:20:57 -0700',
#   'endDate': '2023-09-23 03:20:57 -0700',
#   'value': '57'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 03:35:25 -0700',
#   'startDate': '2023-09-23 03:25:37 -0700',
#   'endDate': '2023-09-23 03:25:37 -0700',
#   'value': '57.5609'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 03:35:27 -0700',
#   'startDate': '2023-09-23 03:26:12 -0700',
#   'endDate': '2023-09-23 03:26:12 -0700',
#   'value': '57'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 03:45:31 -0700',
#   'startDate': '2023-09-23 03:31:02 -0700',
#   'endDate': '2023-09-23 03:31:02 -0700',
#   'value': '57'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 03:45:31 -0700',
#   'startDate': '2023-09-23 03:35:57 -0700',
#   'endDate': '2023-09-23 03:35:57 -0700',
#   'value': '56'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 03:46:19 -0700',
#   'startDate': '2023-09-23 03:41:12 -0700',
#   'endDate': '2023-09-23 03:41:12 -0700',
#   'value': '55'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 03:51:35 -0700',
#   'startDate': '2023-09-23 03:45:57 -0700',
#   'endDate': '2023-09-23 03:45:57 -0700',
#   'value': '54'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 04:00:00 -0700',
#   'startDate': '2023-09-23 03:51:27 -0700',
#   'endDate': '2023-09-23 03:51:27 -0700',
#   'value': '53'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 04:02:38 -0700',
#   'startDate': '2023-09-23 03:55:57 -0700',
#   'endDate': '2023-09-23 03:55:57 -0700',
#   'value': '53'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 04:10:39 -0700',
#   'startDate': '2023-09-23 04:02:57 -0700',
#   'endDate': '2023-09-23 04:02:57 -0700',
#   'value': '46'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 04:15:01 -0700',
#   'startDate': '2023-09-23 04:09:55 -0700',
#   'endDate': '2023-09-23 04:09:55 -0700',
#   'value': '50'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 04:20:40 -0700',
#   'startDate': '2023-09-23 04:14:53 -0700',
#   'endDate': '2023-09-23 04:14:53 -0700',
#   'value': '51'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 04:22:17 -0700',
#   'startDate': '2023-09-23 04:20:26 -0700',
#   'endDate': '2023-09-23 04:20:26 -0700',
#   'value': '53'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 04:32:04 -0700',
#   'startDate': '2023-09-23 04:25:28 -0700',
#   'endDate': '2023-09-23 04:25:28 -0700',
#   'value': '47'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 04:32:04 -0700',
#   'startDate': '2023-09-23 04:28:24 -0700',
#   'endDate': '2023-09-23 04:28:24 -0700',
#   'value': '48'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 04:42:06 -0700',
#   'startDate': '2023-09-23 04:33:37 -0700',
#   'endDate': '2023-09-23 04:33:37 -0700',
#   'value': '50'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 04:42:06 -0700',
#   'startDate': '2023-09-23 04:36:28 -0700',
#   'endDate': '2023-09-23 04:36:28 -0700',
#   'value': '48'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 04:48:38 -0700',
#   'startDate': '2023-09-23 04:45:21 -0700',
#   'endDate': '2023-09-23 04:45:21 -0700',
#   'value': '50'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 04:59:05 -0700',
#   'startDate': '2023-09-23 04:46:46 -0700',
#   'endDate': '2023-09-23 04:46:46 -0700',
#   'value': '51'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 04:59:05 -0700',
#   'startDate': '2023-09-23 04:54:00 -0700',
#   'endDate': '2023-09-23 04:54:00 -0700',
#   'value': '51'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 05:03:17 -0700',
#   'startDate': '2023-09-23 04:56:21 -0700',
#   'endDate': '2023-09-23 04:56:21 -0700',
#   'value': '50'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 05:13:25 -0700',
#   'startDate': '2023-09-23 05:02:56 -0700',
#   'endDate': '2023-09-23 05:02:56 -0700',
#   'value': '49'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 05:13:25 -0700',
#   'startDate': '2023-09-23 05:05:56 -0700',
#   'endDate': '2023-09-23 05:05:56 -0700',
#   'value': '52'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 05:18:55 -0700',
#   'startDate': '2023-09-23 05:11:51 -0700',
#   'endDate': '2023-09-23 05:11:51 -0700',
#   'value': '55'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 05:21:19 -0700',
#   'startDate': '2023-09-23 05:16:21 -0700',
#   'endDate': '2023-09-23 05:16:21 -0700',
#   'value': '58'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 05:29:18 -0700',
#   'startDate': '2023-09-23 05:21:06 -0700',
#   'endDate': '2023-09-23 05:21:06 -0700',
#   'value': '57'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 05:36:11 -0700',
#   'startDate': '2023-09-23 05:27:14 -0700',
#   'endDate': '2023-09-23 05:27:14 -0700',
#   'value': '60'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 05:36:11 -0700',
#   'startDate': '2023-09-23 05:32:16 -0700',
#   'endDate': '2023-09-23 05:32:16 -0700',
#   'value': '55'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 05:42:09 -0700',
#   'startDate': '2023-09-23 05:39:36 -0700',
#   'endDate': '2023-09-23 05:39:36 -0700',
#   'value': '51'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 05:50:03 -0700',
#   'startDate': '2023-09-23 05:41:01 -0700',
#   'endDate': '2023-09-23 05:41:01 -0700',
#   'value': '55'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 05:58:25 -0700',
#   'startDate': '2023-09-23 05:50:30 -0700',
#   'endDate': '2023-09-23 05:50:30 -0700',
#   'value': '53'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 05:58:25 -0700',
#   'startDate': '2023-09-23 05:54:20 -0700',
#   'endDate': '2023-09-23 05:54:20 -0700',
#   'value': '51'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 06:02:11 -0700',
#   'startDate': '2023-09-23 05:57:38 -0700',
#   'endDate': '2023-09-23 05:57:38 -0700',
#   'value': '49'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 06:07:00 -0700',
#   'startDate': '2023-09-23 06:01:50 -0700',
#   'endDate': '2023-09-23 06:01:50 -0700',
#   'value': '98'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 06:11:42 -0700',
#   'startDate': '2023-09-23 06:09:10 -0700',
#   'endDate': '2023-09-23 06:09:10 -0700',
#   'value': '49'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 06:17:35 -0700',
#   'startDate': '2023-09-23 06:11:35 -0700',
#   'endDate': '2023-09-23 06:11:35 -0700',
#   'value': '48'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 06:22:52 -0700',
#   'startDate': '2023-09-23 06:16:00 -0700',
#   'endDate': '2023-09-23 06:16:00 -0700',
#   'value': '48'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 06:26:27 -0700',
#   'startDate': '2023-09-23 06:22:45 -0700',
#   'endDate': '2023-09-23 06:22:45 -0700',
#   'value': '52'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 06:33:54 -0700',
#   'startDate': '2023-09-23 06:26:25 -0700',
#   'endDate': '2023-09-23 06:26:25 -0700',
#   'value': '52'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c1ae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-23 06:36:54 -0700',
#   'startDate': '2023-09-23 06:31:00 -0700',
#   'endDate': '2023-09-23 06:31:00 -0700',
#   'value': '52'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
# ...
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 14:47:52 -0700',
#   'startDate': '2023-09-25 14:42:04 -0700',
#   'endDate': '2023-09-25 14:42:04 -0700',
#   'value': '74'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 14:51:10 -0700',
#   'startDate': '2023-09-25 14:51:09 -0700',
#   'endDate': '2023-09-25 14:51:09 -0700',
#   'value': '127'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 14:53:55 -0700',
#   'startDate': '2023-09-25 14:53:54 -0700',
#   'endDate': '2023-09-25 14:53:54 -0700',
#   'value': '95'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 14:54:46 -0700',
#   'startDate': '2023-09-25 14:47:54 -0700',
#   'endDate': '2023-09-25 14:47:54 -0700',
#   'value': '80'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 15:00:01 -0700',
#   'startDate': '2023-09-25 14:54:52 -0700',
#   'endDate': '2023-09-25 14:54:52 -0700',
#   'value': '87'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 15:01:46 -0700',
#   'startDate': '2023-09-25 14:58:52 -0700',
#   'endDate': '2023-09-25 14:58:52 -0700',
#   'value': '83'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 15:11:11 -0700',
#   'startDate': '2023-09-25 15:03:07 -0700',
#   'endDate': '2023-09-25 15:03:07 -0700',
#   'value': '89'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 15:11:11 -0700',
#   'startDate': '2023-09-25 15:10:45 -0700',
#   'endDate': '2023-09-25 15:10:45 -0700',
#   'value': '73'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 15:18:08 -0700',
#   'startDate': '2023-09-25 15:12:09 -0700',
#   'endDate': '2023-09-25 15:12:09 -0700',
#   'value': '75'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 15:21:11 -0700',
#   'startDate': '2023-09-25 15:19:52 -0700',
#   'endDate': '2023-09-25 15:19:52 -0700',
#   'value': '69'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 15:26:37 -0700',
#   'startDate': '2023-09-25 15:21:45 -0700',
#   'endDate': '2023-09-25 15:21:45 -0700',
#   'value': '71'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 15:34:16 -0700',
#   'startDate': '2023-09-25 15:26:47 -0700',
#   'endDate': '2023-09-25 15:26:47 -0700',
#   'value': '68'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 15:40:59 -0700',
#   'startDate': '2023-09-25 15:31:01 -0700',
#   'endDate': '2023-09-25 15:31:01 -0700',
#   'value': '68'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 15:41:00 -0700',
#   'startDate': '2023-09-25 15:36:34 -0700',
#   'endDate': '2023-09-25 15:36:34 -0700',
#   'value': '71'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 15:43:29 -0700',
#   'startDate': '2023-09-25 15:41:44 -0700',
#   'endDate': '2023-09-25 15:41:44 -0700',
#   'value': '79.6485'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 15:46:48 -0700',
#   'startDate': '2023-09-25 15:41:23 -0700',
#   'endDate': '2023-09-25 15:41:23 -0700',
#   'value': '86'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 15:50:46 -0700',
#   'startDate': '2023-09-25 15:50:45 -0700',
#   'endDate': '2023-09-25 15:50:45 -0700',
#   'value': '102'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 15:51:02 -0700',
#   'startDate': '2023-09-25 15:48:28 -0700',
#   'endDate': '2023-09-25 15:48:28 -0700',
#   'value': '74'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 15:51:09 -0700',
#   'startDate': '2023-09-25 15:51:08 -0700',
#   'endDate': '2023-09-25 15:51:08 -0700',
#   'value': '95'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 15:51:14 -0700',
#   'startDate': '2023-09-25 15:51:13 -0700',
#   'endDate': '2023-09-25 15:51:13 -0700',
#   'value': '96'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 15:51:19 -0700',
#   'startDate': '2023-09-25 15:51:18 -0700',
#   'endDate': '2023-09-25 15:51:18 -0700',
#   'value': '95'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 15:51:24 -0700',
#   'startDate': '2023-09-25 15:51:19 -0700',
#   'endDate': '2023-09-25 15:51:19 -0700',
#   'value': '94'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 15:51:29 -0700',
#   'startDate': '2023-09-25 15:51:28 -0700',
#   'endDate': '2023-09-25 15:51:28 -0700',
#   'value': '89'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 15:51:34 -0700',
#   'startDate': '2023-09-25 15:51:30 -0700',
#   'endDate': '2023-09-25 15:51:30 -0700',
#   'value': '90'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 15:51:39 -0700',
#   'startDate': '2023-09-25 15:51:37 -0700',
#   'endDate': '2023-09-25 15:51:37 -0700',
#   'value': '86'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 15:51:44 -0700',
#   'startDate': '2023-09-25 15:51:40 -0700',
#   'endDate': '2023-09-25 15:51:40 -0700',
#   'value': '86'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 15:54:10 -0700',
#   'startDate': '2023-09-25 15:54:09 -0700',
#   'endDate': '2023-09-25 15:54:09 -0700',
#   'value': '88'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 15:56:28 -0700',
#   'startDate': '2023-09-25 15:56:27 -0700',
#   'endDate': '2023-09-25 15:56:27 -0700',
#   'value': '101'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 16:01:06 -0700',
#   'startDate': '2023-09-25 15:57:55 -0700',
#   'endDate': '2023-09-25 15:57:55 -0700',
#   'value': '69'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 16:06:00 -0700',
#   'startDate': '2023-09-25 16:02:53 -0700',
#   'endDate': '2023-09-25 16:02:53 -0700',
#   'value': '71'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 16:11:01 -0700',
#   'startDate': '2023-09-25 16:07:59 -0700',
#   'endDate': '2023-09-25 16:07:59 -0700',
#   'value': '70'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 16:16:01 -0700',
#   'startDate': '2023-09-25 16:11:21 -0700',
#   'endDate': '2023-09-25 16:11:21 -0700',
#   'value': '70'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 16:21:27 -0700',
#   'startDate': '2023-09-25 16:18:56 -0700',
#   'endDate': '2023-09-25 16:18:56 -0700',
#   'value': '70'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 16:25:58 -0700',
#   'startDate': '2023-09-25 16:21:36 -0700',
#   'endDate': '2023-09-25 16:21:36 -0700',
#   'value': '70'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 16:30:58 -0700',
#   'startDate': '2023-09-25 16:25:57 -0700',
#   'endDate': '2023-09-25 16:25:57 -0700',
#   'value': '69'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 16:36:07 -0700',
#   'startDate': '2023-09-25 16:31:45 -0700',
#   'endDate': '2023-09-25 16:31:45 -0700',
#   'value': '71'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 16:41:03 -0700',
#   'startDate': '2023-09-25 16:38:06 -0700',
#   'endDate': '2023-09-25 16:38:06 -0700',
#   'value': '72'},
#  {'type': 'HKQuantityTypeIdentifierHeartRate',
#   'sourceName': 'Gurdeep’s Apple Watch',
#   'sourceVersion': '10.0.1',
#   'device': '<<HKDevice: 0x2823c2850>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,11, software:10.0.1>',
#   'unit': 'count/min',
#   'creationDate': '2023-09-25 16:46:05 -0700',
#   'startDate': '2023-09-25 16:42:17 -0700',
#   'endDate': '2023-09-25 16:42:17 -0700',
#   'value': '72'},
#  ...]

# %%
# Creating a DataFrame 'record_data' from the list of dictionaries 'record_list'
record_data = pd.DataFrame(record_list)

# Filtering the DataFrame to include only rows where the 'sourceName' column contains the specified string
record_data = record_data.loc[record_data['sourceName'].str.contains('Gurdeep’s Apple Watch')]

# Displaying information about the DataFrame, including data types and non-null counts
display(record_data.info())

# Displaying the filtered DataFrame
display(record_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 509017 entries, 18 to 715666
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   type           509017 non-null  object
#  1   sourceName     509017 non-null  object
#  2   sourceVersion  509017 non-null  object
#  3   unit           503393 non-null  object
#  4   creationDate   509017 non-null  object
#  5   startDate      509017 non-null  object
#  6   endDate        509017 non-null  object
#  7   value          509017 non-null  object
#  8   device         465543 non-null  object
# dtypes: object(9)
# memory usage: 38.8+ MB
# None
#                                                     type  \
# 18                     HKQuantityTypeIdentifierHeartRate
# 19                     HKQuantityTypeIdentifierHeartRate
# 20                     HKQuantityTypeIdentifierHeartRate
# 21                     HKQuantityTypeIdentifierHeartRate
# 22                     HKQuantityTypeIdentifierHeartRate
# ...                                                  ...
# 715662  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 715663  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 715664  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 715665  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 715666  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
#
#                    sourceName sourceVersion       unit  \
# 18      Gurdeep’s Apple Watch        10.0.1  count/min
# 19      Gurdeep’s Apple Watch        10.0.1  count/min
# 20      Gurdeep’s Apple Watch        10.0.1  count/min
# 21      Gurdeep’s Apple Watch        10.0.1  count/min
# 22      Gurdeep’s Apple Watch        10.0.1  count/min
# ...                       ...           ...        ...
# 715662  Gurdeep’s Apple Watch          10.2         ms
# 715663  Gurdeep’s Apple Watch          10.2         ms
# 715664  Gurdeep’s Apple Watch          10.2         ms
# 715665  Gurdeep’s Apple Watch          10.2         ms
# 715666  Gurdeep’s Apple Watch          10.2         ms
#
#                      creationDate                  startDate  \
# 18      2023-09-22 23:31:07 -0700  2023-09-22 23:30:26 -0700
# 19      2023-09-22 23:33:25 -0700  2023-09-22 23:32:21 -0700
# 20      2023-09-22 23:36:02 -0700  2023-09-22 23:35:34 -0700
# 21      2023-09-22 23:41:02 -0700  2023-09-22 23:38:58 -0700
# 22      2023-09-22 23:50:26 -0700  2023-09-22 23:41:31 -0700
# ...                           ...                        ...
# 715662  2024-02-07 02:28:22 -0700  2024-02-07 02:27:21 -0700
# 715663  2024-02-07 06:44:26 -0700  2024-02-07 06:43:26 -0700
# 715664  2024-02-07 10:29:03 -0700  2024-02-07 10:28:02 -0700
# 715665  2024-02-07 15:01:40 -0700  2024-02-07 15:00:39 -0700
# 715666  2024-02-07 18:36:20 -0700  2024-02-07 18:35:19 -0700
#
#                           endDate    value  \
# 18      2023-09-22 23:30:26 -0700       61
# 19      2023-09-22 23:32:21 -0700  65.6369
# 20      2023-09-22 23:35:34 -0700       63
# 21      2023-09-22 23:38:58 -0700       62
# 22      2023-09-22 23:41:31 -0700       68
# ...                           ...      ...
# 715662  2024-02-07 02:28:21 -0700  124.946
# 715663  2024-02-07 06:44:25 -0700  35.8311
# 715664  2024-02-07 10:29:02 -0700  194.816
# 715665  2024-02-07 15:01:38 -0700  87.8208
# 715666  2024-02-07 18:36:16 -0700  116.368
#
#                                                    device
# 18      <<HKDevice: 0x2823c1ae0>, name:Apple Watch, ma...
# 19      <<HKDevice: 0x2823c1ae0>, name:Apple Watch, ma...
# 20      <<HKDevice: 0x2823c1ae0>, name:Apple Watch, ma...
# 21      <<HKDevice: 0x2823c1ae0>, name:Apple Watch, ma...
# 22      <<HKDevice: 0x2823c1ae0>, name:Apple Watch, ma...
# ...                                                   ...
# 715662  <<HKDevice: 0x2823a5680>, name:Apple Watch, ma...
# 715663  <<HKDevice: 0x2823a5680>, name:Apple Watch, ma...
# 715664  <<HKDevice: 0x2823a5680>, name:Apple Watch, ma...
# 715665  <<HKDevice: 0x2823a5680>, name:Apple Watch, ma...
# 715666  <<HKDevice: 0x2823a5680>, name:Apple Watch, ma...
#
# [509017 rows x 9 columns]

# %%
# Checking unique values in the 'type' column of the DataFrame 'record_data'
unique_types = record_data.type.unique()

# Displaying the unique health metrics captured by the Apple Watch
unique_types
# Out:
# array(['HKQuantityTypeIdentifierHeartRate',
#        'HKQuantityTypeIdentifierRespiratoryRate',
#        'HKQuantityTypeIdentifierStepCount',
#        'HKQuantityTypeIdentifierDistanceWalkingRunning',
#        'HKQuantityTypeIdentifierBasalEnergyBurned',
#        'HKQuantityTypeIdentifierActiveEnergyBurned',
#        'HKQuantityTypeIdentifierFlightsClimbed',
#        'HKQuantityTypeIdentifierAppleExerciseTime',
#        'HKQuantityTypeIdentifierRestingHeartRate',
#        'HKQuantityTypeIdentifierVO2Max',
#        'HKQuantityTypeIdentifierWalkingHeartRateAverage',
#        'HKQuantityTypeIdentifierEnvironmentalAudioExposure',
#        'HKQuantityTypeIdentifierHeadphoneAudioExposure',
#        'HKQuantityTypeIdentifierAppleStandTime',
#        'HKQuantityTypeIdentifierStairAscentSpeed',
#        'HKQuantityTypeIdentifierStairDescentSpeed',
#        'HKQuantityTypeIdentifierHeartRateRecoveryOneMinute',
#        'HKQuantityTypeIdentifierEnvironmentalSoundReduction',
#        'HKQuantityTypeIdentifierTimeInDaylight',
#        'HKQuantityTypeIdentifierPhysicalEffort',
#        'HKCategoryTypeIdentifierSleepAnalysis',
#        'HKCategoryTypeIdentifierAppleStandHour',
#        'HKCategoryTypeIdentifierMindfulSession',
#        'HKCategoryTypeIdentifierLowHeartRateEvent',
#        'HKCategoryTypeIdentifierAudioExposureEvent',
#        'HKQuantityTypeIdentifierHeartRateVariabilitySDNN'], dtype=object)

# %%
# Filtering the DataFrame 'record_data' to include only rows where the 'type' column contains the specified substring
filtered_records = record_data.loc[record_data['type'].str.contains("ActiveEnergyBurned")]

# Displaying the resulting DataFrame pertaining to this specific Apple Watch health metric
filtered_records
# Out:
#                                               type             sourceName  \
# 406116  HKQuantityTypeIdentifierActiveEnergyBurned  Gurdeep’s Apple Watch
# 406117  HKQuantityTypeIdentifierActiveEnergyBurned  Gurdeep’s Apple Watch
# 406118  HKQuantityTypeIdentifierActiveEnergyBurned  Gurdeep’s Apple Watch
# 406119  HKQuantityTypeIdentifierActiveEnergyBurned  Gurdeep’s Apple Watch
# 406120  HKQuantityTypeIdentifierActiveEnergyBurned  Gurdeep’s Apple Watch
# ...                                            ...                    ...
# 567142  HKQuantityTypeIdentifierActiveEnergyBurned  Gurdeep’s Apple Watch
# 567143  HKQuantityTypeIdentifierActiveEnergyBurned  Gurdeep’s Apple Watch
# 567144  HKQuantityTypeIdentifierActiveEnergyBurned  Gurdeep’s Apple Watch
# 567145  HKQuantityTypeIdentifierActiveEnergyBurned  Gurdeep’s Apple Watch
# 567146  HKQuantityTypeIdentifierActiveEnergyBurned  Gurdeep’s Apple Watch
#
#        sourceVersion unit               creationDate  \
# 406116        10.0.1  Cal  2023-09-22 23:30:17 -0700
# 406117        10.0.1  Cal  2023-09-22 23:33:17 -0700
# 406118        10.0.1  Cal  2023-09-22 23:33:17 -0700
# 406119        10.0.1  Cal  2023-09-22 23:40:53 -0700
# 406120        10.0.1  Cal  2023-09-22 23:40:53 -0700
# ...              ...  ...                        ...
# 567142          10.2  Cal  2024-02-07 18:39:51 -0700
# 567143          10.2  Cal  2024-02-07 18:53:23 -0700
# 567144          10.2  Cal  2024-02-07 18:53:23 -0700
# 567145          10.2  Cal  2024-02-07 19:04:13 -0700
# 567146          10.2  Cal  2024-02-07 19:04:13 -0700
#
#                         startDate                    endDate  value  \
# 406116  2023-09-22 23:29:34 -0700  2023-09-22 23:29:44 -0700  0.043
# 406117  2023-09-22 23:30:55 -0700  2023-09-22 23:31:36 -0700  0.307
# 406118  2023-09-22 23:32:27 -0700  2023-09-22 23:32:58 -0700  0.159
# 406119  2023-09-22 23:32:58 -0700  2023-09-22 23:33:59 -0700  0.356
# 406120  2023-09-22 23:33:59 -0700  2023-09-22 23:34:09 -0700  0.094
# ...                           ...                        ...    ...
# 567142  2024-02-07 18:29:34 -0700  2024-02-07 18:39:35 -0700  6.153
# 567143  2024-02-07 18:39:35 -0700  2024-02-07 18:49:36 -0700  8.768
# 567144  2024-02-07 18:49:36 -0700  2024-02-07 18:52:29 -0700  1.091
# 567145  2024-02-07 18:52:29 -0700  2024-02-07 18:53:10 -0700  0.209
# 567146  2024-02-07 18:53:10 -0700  2024-02-07 19:03:11 -0700   3.01
#
#                                                    device
# 406116  <<HKDevice: 0x2823cf8e0>, name:Apple Watch, ma...
# 406117  <<HKDevice: 0x2823cf8e0>, name:Apple Watch, ma...
# 406118  <<HKDevice: 0x2823cf8e0>, name:Apple Watch, ma...
# 406119  <<HKDevice: 0x2823cf8e0>, name:Apple Watch, ma...
# 406120  <<HKDevice: 0x2823cf8e0>, name:Apple Watch, ma...
# ...                                                   ...
# 567142  <<HKDevice: 0x2823cfb60>, name:Apple Watch, ma...
# 567143  <<HKDevice: 0x2823cfb60>, name:Apple Watch, ma...
# 567144  <<HKDevice: 0x2823cfb60>, name:Apple Watch, ma...
# 567145  <<HKDevice: 0x2823cfb60>, name:Apple Watch, ma...
# 567146  <<HKDevice: 0x2823cfb60>, name:Apple Watch, ma...
#
# [161031 rows x 9 columns]

# %%
# Creating a new DataFrame 'record_data_cleaned' by dropping specified columns from the original DataFrame 'record_data'
# The specified columns to be dropped are 'sourceName', 'sourceVersion', 'creationDate', 'endDate', and 'device'
record_data_cleaned = record_data.drop(['sourceName', 'sourceVersion', 'creationDate', 'endDate', 'device'], axis=1)

# Displaying the resulting cleaned DataFrame
record_data_cleaned
# Out:
#                                                     type       unit  \
# 18                     HKQuantityTypeIdentifierHeartRate  count/min
# 19                     HKQuantityTypeIdentifierHeartRate  count/min
# 20                     HKQuantityTypeIdentifierHeartRate  count/min
# 21                     HKQuantityTypeIdentifierHeartRate  count/min
# 22                     HKQuantityTypeIdentifierHeartRate  count/min
# ...                                                  ...        ...
# 715662  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 715663  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 715664  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 715665  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 715666  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
#
#                         startDate    value
# 18      2023-09-22 23:30:26 -0700       61
# 19      2023-09-22 23:32:21 -0700  65.6369
# 20      2023-09-22 23:35:34 -0700       63
# 21      2023-09-22 23:38:58 -0700       62
# 22      2023-09-22 23:41:31 -0700       68
# ...                           ...      ...
# 715662  2024-02-07 02:27:21 -0700  124.946
# 715663  2024-02-07 06:43:26 -0700  35.8311
# 715664  2024-02-07 10:28:02 -0700  194.816
# 715665  2024-02-07 15:00:39 -0700  87.8208
# 715666  2024-02-07 18:35:19 -0700  116.368
#
# [509017 rows x 4 columns]

# %%
# Converting the 'startDate' column in the DataFrame 'record_data_cleaned' to datetime format
record_data_cleaned['startDate'] = pd.to_datetime(record_data_cleaned['startDate'])

# Displaying the DataFrame with the 'startDate' column converted to datetime
record_data_cleaned
# Out:
#                                                     type       unit  \
# 18                     HKQuantityTypeIdentifierHeartRate  count/min
# 19                     HKQuantityTypeIdentifierHeartRate  count/min
# 20                     HKQuantityTypeIdentifierHeartRate  count/min
# 21                     HKQuantityTypeIdentifierHeartRate  count/min
# 22                     HKQuantityTypeIdentifierHeartRate  count/min
# ...                                                  ...        ...
# 715662  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 715663  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 715664  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 715665  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 715666  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
#
#                        startDate    value
# 18     2023-09-22 23:30:26-07:00       61
# 19     2023-09-22 23:32:21-07:00  65.6369
# 20     2023-09-22 23:35:34-07:00       63
# 21     2023-09-22 23:38:58-07:00       62
# 22     2023-09-22 23:41:31-07:00       68
# ...                          ...      ...
# 715662 2024-02-07 02:27:21-07:00  124.946
# 715663 2024-02-07 06:43:26-07:00  35.8311
# 715664 2024-02-07 10:28:02-07:00  194.816
# 715665 2024-02-07 15:00:39-07:00  87.8208
# 715666 2024-02-07 18:35:19-07:00  116.368
#
# [509017 rows x 4 columns]

# %%
# Extracting the day, date, and month information from the 'startDate' column
# Creating new columns 'day', 'date', and 'month' in the DataFrame 'record_data_cleaned'
record_data_cleaned['day'] = record_data_cleaned['startDate'].dt.day
record_data_cleaned['date'] = record_data_cleaned['startDate'].dt.date
record_data_cleaned['month'] = record_data_cleaned['startDate'].dt.month

# Displaying the DataFrame with the new columns added
record_data_cleaned
# Out:
#                                                     type       unit  \
# 18                     HKQuantityTypeIdentifierHeartRate  count/min
# 19                     HKQuantityTypeIdentifierHeartRate  count/min
# 20                     HKQuantityTypeIdentifierHeartRate  count/min
# 21                     HKQuantityTypeIdentifierHeartRate  count/min
# 22                     HKQuantityTypeIdentifierHeartRate  count/min
# ...                                                  ...        ...
# 715662  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 715663  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 715664  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 715665  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 715666  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
#
#                        startDate    value  day        date  month
# 18     2023-09-22 23:30:26-07:00       61   22  2023-09-22      9
# 19     2023-09-22 23:32:21-07:00  65.6369   22  2023-09-22      9
# 20     2023-09-22 23:35:34-07:00       63   22  2023-09-22      9
# 21     2023-09-22 23:38:58-07:00       62   22  2023-09-22      9
# 22     2023-09-22 23:41:31-07:00       68   22  2023-09-22      9
# ...                          ...      ...  ...         ...    ...
# 715662 2024-02-07 02:27:21-07:00  124.946    7  2024-02-07      2
# 715663 2024-02-07 06:43:26-07:00  35.8311    7  2024-02-07      2
# 715664 2024-02-07 10:28:02-07:00  194.816    7  2024-02-07      2
# 715665 2024-02-07 15:00:39-07:00  87.8208    7  2024-02-07      2
# 715666 2024-02-07 18:35:19-07:00  116.368    7  2024-02-07      2
#
# [509017 rows x 7 columns]

# %%
# Converting the 'value' column in the DataFrame 'record_data_cleaned' to numeric format
# Using 'coerce' to handle any values that cannot be converted to numeric by replacing them with NaN
record_data_cleaned['value'] = pd.to_numeric(record_data_cleaned['value'], errors='coerce')

# %%
# Removing specified substrings from the 'type' column in the DataFrame 'record_data_cleaned'
record_data_cleaned['type'] = record_data_cleaned['type'].str.replace('HKQuantityTypeIdentifier', '')
record_data_cleaned['type'] = record_data_cleaned['type'].str.replace('HKDataType', '')
record_data_cleaned['type'] = record_data_cleaned['type'].str.replace('HKCategoryTypeIdentifier', '')

# %%
# Displaying the DataFrame with the 'type' column cleaned
record_data_cleaned
# Out:
#                             type       unit                 startDate  \
# 18                     HeartRate  count/min 2023-09-22 23:30:26-07:00
# 19                     HeartRate  count/min 2023-09-22 23:32:21-07:00
# 20                     HeartRate  count/min 2023-09-22 23:35:34-07:00
# 21                     HeartRate  count/min 2023-09-22 23:38:58-07:00
# 22                     HeartRate  count/min 2023-09-22 23:41:31-07:00
# ...                          ...        ...                       ...
# 715662  HeartRateVariabilitySDNN         ms 2024-02-07 02:27:21-07:00
# 715663  HeartRateVariabilitySDNN         ms 2024-02-07 06:43:26-07:00
# 715664  HeartRateVariabilitySDNN         ms 2024-02-07 10:28:02-07:00
# 715665  HeartRateVariabilitySDNN         ms 2024-02-07 15:00:39-07:00
# 715666  HeartRateVariabilitySDNN         ms 2024-02-07 18:35:19-07:00
#
#            value  day        date  month
# 18       61.0000   22  2023-09-22      9
# 19       65.6369   22  2023-09-22      9
# 20       63.0000   22  2023-09-22      9
# 21       62.0000   22  2023-09-22      9
# 22       68.0000   22  2023-09-22      9
# ...          ...  ...         ...    ...
# 715662  124.9460    7  2024-02-07      2
# 715663   35.8311    7  2024-02-07      2
# 715664  194.8160    7  2024-02-07      2
# 715665   87.8208    7  2024-02-07      2
# 715666  116.3680    7  2024-02-07      2
#
# [509017 rows x 7 columns]

# %%
# Extracting unique values from the 'type' column for all of the Apple Watch healh metrics
record_types = record_data_cleaned['type'].unique()

# Displaying the unique record types
record_types
# Out:
# array(['HeartRate', 'RespiratoryRate', 'StepCount',
#        'DistanceWalkingRunning', 'BasalEnergyBurned',
#        'ActiveEnergyBurned', 'FlightsClimbed', 'AppleExerciseTime',
#        'RestingHeartRate', 'VO2Max', 'WalkingHeartRateAverage',
#        'EnvironmentalAudioExposure', 'HeadphoneAudioExposure',
#        'AppleStandTime', 'StairAscentSpeed', 'StairDescentSpeed',
#        'HeartRateRecoveryOneMinute', 'EnvironmentalSoundReduction',
#        'TimeInDaylight', 'PhysicalEffort', 'SleepAnalysis',
#        'AppleStandHour', 'MindfulSession', 'LowHeartRateEvent',
#        'AudioExposureEvent', 'HeartRateVariabilitySDNN'], dtype=object)

# %%
# Reordering the columns in the DataFrame 'record_data_cleaned'
# Selecting specific columns in the specified order: 'type', 'date', 'day', 'month', 'value', 'unit'
record_data_cleaned = record_data_cleaned[['type', 'date', 'day', 'month', 'value', 'unit']]

# Displaying the DataFrame with the columns reordered
display(record_data_cleaned)
# Out:
#                             type        date  day  month     value       unit
# 18                     HeartRate  2023-09-22   22      9   61.0000  count/min
# 19                     HeartRate  2023-09-22   22      9   65.6369  count/min
# 20                     HeartRate  2023-09-22   22      9   63.0000  count/min
# 21                     HeartRate  2023-09-22   22      9   62.0000  count/min
# 22                     HeartRate  2023-09-22   22      9   68.0000  count/min
# ...                          ...         ...  ...    ...       ...        ...
# 715662  HeartRateVariabilitySDNN  2024-02-07    7      2  124.9460         ms
# 715663  HeartRateVariabilitySDNN  2024-02-07    7      2   35.8311         ms
# 715664  HeartRateVariabilitySDNN  2024-02-07    7      2  194.8160         ms
# 715665  HeartRateVariabilitySDNN  2024-02-07    7      2   87.8208         ms
# 715666  HeartRateVariabilitySDNN  2024-02-07    7      2  116.3680         ms
#
# [509017 rows x 6 columns]

# %%
# Creating an empty dictionary to store DataFrames for each record type
record_data_df_dict = {}

# List of health metrics for which DataFrames will be created
record_types = [
    'BodyMass',
    'HeartRate',
    'RestingHeartRate',
    'WalkingHeartRateAverage',
    'HeartRateVariabilitySDNN',
    'WalkingSpeed',
    'StepCount',
    'DistanceWalkingRunning',
    'BasalEnergyBurned',
    'ActiveEnergyBurned',
    'AppleExerciseTime',
    'AppleStandTime',
    'AppleStandHour',
    'VO2Max',
    'SleepDurationGoal',
    'SleepAnalysis',
    'AudioExposureEvent'
]

# Iterating through each record type to create a DataFrame and store it in the dictionary
for record_type in record_types:
    # Filtering the main DataFrame based on the current record type
    filtered_data = record_data_cleaned.loc[(record_data_cleaned['type'].str.contains(record_type))]
    
    # Renaming the 'value' column to match the record type
    # Sorting the DataFrame by the 'date' column
    record_data_df_dict[record_type] = filtered_data.rename(columns={'value': record_type}).sort_values(by='date')

# %%
# Creating an empty dictionary to store DataFrames with daily aggregations for specific record types
record_data_df_dict_daily = {}

# List of record types to be aggregated on a daily basis
daily_monthly_sum = [
    'StepCount',
    'DistanceWalkingRunning',
    'BasalEnergyBurned',
    'ActiveEnergyBurned',
    'AppleExerciseTime',
    'AppleStandTime',
    'AppleStandHour'
]

# Iterating through each record type to create a DataFrame with daily aggregations
for key in daily_monthly_sum:
    # Grouping the DataFrame by 'date', aggregating 'sum' for the specified column and finding the mode of 'day'
    # Resetting the index to have 'date' as a regular column
    record_data_df_dict_daily[key] = record_data_df_dict[key].groupby(record_data_df_dict[key]['date']).agg({key: 'sum', 'day': lambda x: x.mode().iat[0]}).reset_index()

# %%
# Creating an empty dictionary to store DataFrames with monthly aggregations for specific record types
record_data_df_dict_monthly = {}

# Iterating through each record type to create a DataFrame with monthly aggregations
for key in daily_monthly_sum:
    # Grouping the DataFrame by the formatted 'date' (Year-Month), aggregating 'sum' for the specified column, and finding the mode of 'month'
    # Resetting the index to have the formatted 'date' as a regular column
    record_data_df_dict_monthly[key] = record_data_df_dict[key].groupby(record_data_df_dict[key]['date'].apply(lambda x: x.strftime('%Y-%m'))).agg({key: 'sum', 'month': lambda x: x.mode().iat[0]}).reset_index()

# %% [markdown]
# ## Data Collection and Cleaning in Workout Data

# %%
# Creating an empty list to store dictionaries for each workout
final_workout_dict = []

# Extracting 'Workout' elements from the XML tree
workout_list = list(root.iter('Workout'))

# Iterating through each 'Workout' element
for i in range(len(workout_list)):
    workout_dict = workout_list[i].attrib
    WorkoutStatisticsList = list(workout_list[i].iter("WorkoutStatistics"))

    # Iterating through each 'WorkoutStatistics' element
    for i, WorkoutStatistics in enumerate(WorkoutStatisticsList):
        if "ActiveEnergyBurned" in WorkoutStatistics.attrib['type']:
            workout_dict['activeEnergyBurned'] = WorkoutStatistics.attrib['sum']
        if "BasalEnergyBurned" in WorkoutStatistics.attrib['type']:
            workout_dict['basalEnergyBurned'] = WorkoutStatistics.attrib['sum']

    final_workout_dict.append(workout_dict)

# Creating a DataFrame 'final_workout_df' from the list of workout dictionaries
final_workout_df = pd.DataFrame(final_workout_dict)

# Displaying the head of the final_workout_df DataFrame
final_workout_df.head()
# Out:
#                                 workoutActivityType           duration  \
# 0  HKWorkoutActivityTypeTraditionalStrengthTraining   73.3147721350193
# 1                      HKWorkoutActivityTypeWalking  20.45117767850558
# 2                      HKWorkoutActivityTypeWalking  15.02275181810061
# 3  HKWorkoutActivityTypeTraditionalStrengthTraining  79.21044928232828
# 4                      HKWorkoutActivityTypeWalking  8.231149383385976
#
#   durationUnit             sourceName sourceVersion  \
# 0          min  Gurdeep’s Apple Watch        10.0.1
# 1          min  Gurdeep’s Apple Watch        10.0.1
# 2          min  Gurdeep’s Apple Watch        10.0.1
# 3          min  Gurdeep’s Apple Watch        10.0.1
# 4          min  Gurdeep’s Apple Watch        10.0.1
#
#                                               device  \
# 0  <<HKDevice: 0x2823d5220>, name:Apple Watch, ma...
# 1  <<HKDevice: 0x2823d5220>, name:Apple Watch, ma...
# 2  <<HKDevice: 0x2823d5220>, name:Apple Watch, ma...
# 3  <<HKDevice: 0x2823d5220>, name:Apple Watch, ma...
# 4  <<HKDevice: 0x2823d5220>, name:Apple Watch, ma...
#
#                 creationDate                  startDate  \
# 0  2023-09-23 15:23:28 -0700  2023-09-23 14:09:44 -0700
# 1  2023-09-25 07:59:57 -0700  2023-09-25 07:39:29 -0700
# 2  2023-09-25 17:11:09 -0700  2023-09-25 16:56:06 -0700
# 3  2023-09-26 15:01:30 -0700  2023-09-26 13:42:14 -0700
# 4  2023-09-27 11:00:44 -0700  2023-09-27 10:52:29 -0700
#
#                      endDate activeEnergyBurned basalEnergyBurned
# 0  2023-09-23 15:23:25 -0700            376.484           114.259
# 1  2023-09-25 07:59:56 -0700             89.946           31.4567
# 2  2023-09-25 17:11:08 -0700            69.0088           23.1168
# 3  2023-09-26 15:01:27 -0700            685.162           120.565
# 4  2023-09-27 11:00:43 -0700            25.0152           12.6976

# %%
# Dropping unnecessary columns from the original DataFrame
final_workout_df_cleaned = final_workout_df.drop(['sourceName','sourceVersion', 'device', 'creationDate','endDate'], axis=1)

# Transforming 'startDate' into date format
final_workout_df_cleaned['Date'] = pd.to_datetime(final_workout_df['startDate']).dt.strftime('%Y-%m-%d')
final_workout_df_cleaned['Day'] = pd.to_datetime(final_workout_df['startDate']).dt.strftime('%A')

# Renaming 'HKWorkoutActivityType' in the 'workoutActivityType' column
final_workout_df_cleaned['workoutActivityType'] = final_workout_df['workoutActivityType'].str.replace('HKWorkoutActivityType','')

# Reordering columns in the DataFrame
final_workout_df_cleaned = final_workout_df_cleaned[['Day', 'Date', 'workoutActivityType', 'duration', 'durationUnit', 'activeEnergyBurned', 'basalEnergyBurned']]

# Converting data type of 'duration' from object to float
final_workout_df_cleaned['duration'] = final_workout_df['duration'].astype(float)

# Converting data type of 'activeEnergyBurned' and 'basalEnergyBurned' from object to float
final_workout_df_cleaned['activeEnergyBurned'] = final_workout_df['activeEnergyBurned'].astype(float)
final_workout_df_cleaned['basalEnergyBurned'] = final_workout_df['basalEnergyBurned'].astype(float)

# Displaying the cleaned and transformed DataFrame
display(final_workout_df_cleaned)
# Out:
#            Day        Date          workoutActivityType   duration  \
# 0     Saturday  2023-09-23  TraditionalStrengthTraining  73.314772
# 1       Monday  2023-09-25                      Walking  20.451178
# 2       Monday  2023-09-25                      Walking  15.022752
# 3      Tuesday  2023-09-26  TraditionalStrengthTraining  79.210449
# 4    Wednesday  2023-09-27                      Walking   8.231149
# ..         ...         ...                          ...        ...
# 129     Monday  2024-01-29                      Walking  13.169210
# 130     Monday  2024-01-29                      Walking  15.732601
# 131    Tuesday  2024-01-30                      Walking  12.040766
# 132     Monday  2024-02-05  TraditionalStrengthTraining  57.929649
# 133    Tuesday  2024-02-06  TraditionalStrengthTraining  61.592906
#
#     durationUnit  activeEnergyBurned  basalEnergyBurned
# 0            min            376.4840           114.2590
# 1            min             89.9460            31.4567
# 2            min             69.0088            23.1168
# 3            min            685.1620           120.5650
# 4            min             25.0152            12.6976
# ..           ...                 ...                ...
# 129          min             51.9713            20.3200
# 130          min             63.5388            24.6931
# 131          min             54.0526            18.8228
# 132          min            624.6000            89.8521
# 133          min            405.1510            96.3036
#
# [134 rows x 7 columns]

# %% [markdown]
# ## Creating separate CSV files for each health metric by extracting dataframes.

# %%
for record in record_data_df_dict:
    record_data_df_dict[record].to_csv(record+".csv")

# %%
for record in record_data_df_dict_daily:
    record_data_df_dict_daily[record].to_csv(record+"Daily.csv")

# %%
for record in record_data_df_dict_monthly:
    record_data_df_dict_monthly[record].to_csv(record+"Monthly.csv")

# %%
final_workout_df_cleaned.to_csv("Workouts.csv")
